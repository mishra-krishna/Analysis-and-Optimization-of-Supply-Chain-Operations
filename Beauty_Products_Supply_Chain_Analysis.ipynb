# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
from sklearn.tree import DecisionTreeRegressor

# %%
df = pd.read_csv('supply_chain_data.csv')

# %%
df.head()
# Out:
#   Product type   SKU      Price  Availability  Number of products sold  \
# 0     haircare  SKU0  69.808006            55                      802
# 1     skincare  SKU1  14.843523            95                      736
# 2     haircare  SKU2  11.319683            34                        8
# 3     skincare  SKU3  61.163343            68                       83
# 4     skincare  SKU4   4.805496            26                      871
#
#    Revenue generated Customer demographics  Stock levels  Lead times  \
# 0        8661.996792            Non-binary            58           7
# 1        7460.900065                Female            53          30
# 2        9577.749626               Unknown             1          10
# 3        7766.836426            Non-binary            23          13
# 4        2686.505152            Non-binary             5           3
#
#    Order quantities  ...  Location Lead time  Production volumes  \
# 0                96  ...    Mumbai        29                 215
# 1                37  ...    Mumbai        23                 517
# 2                88  ...    Mumbai        12                 971
# 3                59  ...   Kolkata        24                 937
# 4                56  ...     Delhi         5                 414
#
#   Manufacturing lead time Manufacturing costs  Inspection results  \
# 0                      29           46.279879             Pending
# 1                      30           33.616769             Pending
# 2                      27           30.688019             Pending
# 3                      18           35.624741                Fail
# 4                       3           92.065161                Fail
#
#    Defect rates  Transportation modes   Routes       Costs
# 0      0.226410                  Road  Route B  187.752075
# 1      4.854068                  Road  Route B  503.065579
# 2      4.580593                   Air  Route C  141.920282
# 3      4.746649                  Rail  Route A  254.776159
# 4      3.145580                   Air  Route A  923.440632
#
# [5 rows x 24 columns]

# %%
df.describe()
#Descriptive Values from different columns of the dataset
# Out:
#             Price  Availability  Number of products sold  Revenue generated  \
# count  100.000000    100.000000               100.000000         100.000000
# mean    49.462461     48.400000               460.990000        5776.048187
# std     31.168193     30.743317               303.780074        2732.841744
# min      1.699976      1.000000                 8.000000        1061.618523
# 25%     19.597823     22.750000               184.250000        2812.847151
# 50%     51.239831     43.500000               392.500000        6006.352023
# 75%     77.198228     75.000000               704.250000        8253.976921
# max     99.171329    100.000000               996.000000        9866.465458
#
#        Stock levels  Lead times  Order quantities  Shipping times  \
# count    100.000000  100.000000        100.000000      100.000000
# mean      47.770000   15.960000         49.220000        5.750000
# std       31.369372    8.785801         26.784429        2.724283
# min        0.000000    1.000000          1.000000        1.000000
# 25%       16.750000    8.000000         26.000000        3.750000
# 50%       47.500000   17.000000         52.000000        6.000000
# 75%       73.000000   24.000000         71.250000        8.000000
# max      100.000000   30.000000         96.000000       10.000000
#
#        Shipping costs   Lead time  Production volumes  \
# count      100.000000  100.000000          100.000000
# mean         5.548149   17.080000          567.840000
# std          2.651376    8.846251          263.046861
# min          1.013487    1.000000          104.000000
# 25%          3.540248   10.000000          352.000000
# 50%          5.320534   18.000000          568.500000
# 75%          7.601695   25.000000          797.000000
# max          9.929816   30.000000          985.000000
#
#        Manufacturing lead time  Manufacturing costs  Defect rates       Costs
# count                100.00000           100.000000    100.000000  100.000000
# mean                  14.77000            47.266693      2.277158  529.245782
# std                    8.91243            28.982841      1.461366  258.301696
# min                    1.00000             1.085069      0.018608  103.916248
# 25%                    7.00000            22.983299      1.009650  318.778455
# 50%                   14.00000            45.905622      2.141863  520.430444
# 75%                   23.00000            68.621026      3.563995  763.078231
# max                   30.00000            99.466109      4.939255  997.413450

# %%
df.isnull().sum()
#There are no missing values in the dataset
# Out:
# Product type               0
# SKU                        0
# Price                      0
# Availability               0
# Number of products sold    0
# Revenue generated          0
# Customer demographics      0
# Stock levels               0
# Lead times                 0
# Order quantities           0
# Shipping times             0
# Shipping carriers          0
# Shipping costs             0
# Supplier name              0
# Location                   0
# Lead time                  0
# Production volumes         0
# Manufacturing lead time    0
# Manufacturing costs        0
# Inspection results         0
# Defect rates               0
# Transportation modes       0
# Routes                     0
# Costs                      0
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 24 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Product type             100 non-null    object
#  1   SKU                      100 non-null    object
#  2   Price                    100 non-null    float64
#  3   Availability             100 non-null    int64
#  4   Number of products sold  100 non-null    int64
#  5   Revenue generated        100 non-null    float64
#  6   Customer demographics    100 non-null    object
#  7   Stock levels             100 non-null    int64
#  8   Lead times               100 non-null    int64
#  9   Order quantities         100 non-null    int64
#  10  Shipping times           100 non-null    int64
#  11  Shipping carriers        100 non-null    object
#  12  Shipping costs           100 non-null    float64
#  13  Supplier name            100 non-null    object
#  14  Location                 100 non-null    object
#  15  Lead time                100 non-null    int64
#  16  Production volumes       100 non-null    int64
#  17  Manufacturing lead time  100 non-null    int64
#  18  Manufacturing costs      100 non-null    float64
#  19  Inspection results       100 non-null    object
#  20  Defect rates             100 non-null    float64
#  21  Transportation modes     100 non-null    object
#  22  Routes                   100 non-null    object
#  23  Costs                    100 non-null    float64
# dtypes: float64(6), int64(9), object(9)
# memory usage: 18.9+ KB

# %%
categorical_columns = ['Product type','Customer demographics', 'Shipping carriers', 'Supplier name', 'Location','Location','Inspection results','Transportation modes','Routes']
df2 = pd.get_dummies(df, columns=categorical_columns)
df2.head()
#Converted categorical variables using one hot encoding for analysis
# Out:
#     SKU      Price  Availability  Number of products sold  Revenue generated  \
# 0  SKU0  69.808006            55                      802        8661.996792
# 1  SKU1  14.843523            95                      736        7460.900065
# 2  SKU2  11.319683            34                        8        9577.749626
# 3  SKU3  61.163343            68                       83        7766.836426
# 4  SKU4   4.805496            26                      871        2686.505152
#
#    Stock levels  Lead times  Order quantities  Shipping times  Shipping costs  \
# 0            58           7                96               4        2.956572
# 1            53          30                37               2        9.716575
# 2             1          10                88               2        8.054479
# 3            23          13                59               6        1.729569
# 4             5           3                56               8        3.890548
#
#    ...  Inspection results_Fail  Inspection results_Pass  \
# 0  ...                    False                    False
# 1  ...                    False                    False
# 2  ...                    False                    False
# 3  ...                     True                    False
# 4  ...                     True                    False
#
#    Inspection results_Pending  Transportation modes_Air  \
# 0                        True                     False
# 1                        True                     False
# 2                        True                      True
# 3                       False                     False
# 4                       False                      True
#
#    Transportation modes_Rail  Transportation modes_Road  \
# 0                      False                       True
# 1                      False                       True
# 2                      False                      False
# 3                       True                      False
# 4                      False                      False
#
#    Transportation modes_Sea  Routes_Route A  Routes_Route B  Routes_Route C
# 0                     False           False            True           False
# 1                     False           False            True           False
# 2                     False           False           False            True
# 3                     False            True           False           False
# 4                     False            True           False           False
#
# [5 rows x 51 columns]

# %%
matrix = df2.drop(columns=['SKU']).corr()

# %%
#Checking for Linear Relationships between columns in the dataset
filtered_values = matrix[
    (matrix >= 0.5) & (matrix < 1) |
    (matrix <= -0.5) & (matrix > -1)
]
print(filtered_values)
# Out:
#                                   Price  Availability  \
# Price                               NaN           NaN
# Availability                        NaN           NaN
# Number of products sold             NaN           NaN
# Revenue generated                   NaN           NaN
# Stock levels                        NaN           NaN
# Lead times                          NaN           NaN
# Order quantities                    NaN           NaN
# Shipping times                      NaN           NaN
# Shipping costs                      NaN           NaN
# Lead time                           NaN           NaN
# Production volumes                  NaN           NaN
# Manufacturing lead time             NaN           NaN
# Manufacturing costs                 NaN           NaN
# Defect rates                        NaN           NaN
# Costs                               NaN           NaN
# Product type_cosmetics              NaN           NaN
# Product type_haircare               NaN           NaN
# Product type_skincare               NaN           NaN
# Customer demographics_Female        NaN           NaN
# Customer demographics_Male          NaN           NaN
# Customer demographics_Non-binary    NaN           NaN
# Customer demographics_Unknown       NaN           NaN
# Shipping carriers_Carrier A         NaN           NaN
# Shipping carriers_Carrier B         NaN           NaN
# Shipping carriers_Carrier C         NaN           NaN
# Supplier name_Supplier 1            NaN           NaN
# Supplier name_Supplier 2            NaN           NaN
# Supplier name_Supplier 3            NaN           NaN
# Supplier name_Supplier 4            NaN           NaN
# Supplier name_Supplier 5            NaN           NaN
# Location_Bangalore                  NaN           NaN
# Location_Chennai                    NaN           NaN
# Location_Delhi                      NaN           NaN
# Location_Kolkata                    NaN           NaN
# Location_Mumbai                     NaN           NaN
# Location_Bangalore                  NaN           NaN
# Location_Chennai                    NaN           NaN
# Location_Delhi                      NaN           NaN
# Location_Kolkata                    NaN           NaN
# Location_Mumbai                     NaN           NaN
# Inspection results_Fail             NaN           NaN
# Inspection results_Pass             NaN           NaN
# Inspection results_Pending          NaN           NaN
# Transportation modes_Air            NaN           NaN
# Transportation modes_Rail           NaN           NaN
# Transportation modes_Road           NaN           NaN
# Transportation modes_Sea            NaN           NaN
# Routes_Route A                      NaN           NaN
# Routes_Route B                      NaN           NaN
# Routes_Route C                      NaN           NaN
#
#                                   Number of products sold  Revenue generated  \
# Price                                                 NaN                NaN
# Availability                                          NaN                NaN
# Number of products sold                               NaN                NaN
# Revenue generated                                     NaN                NaN
# Stock levels                                          NaN                NaN
# Lead times                                            NaN                NaN
# Order quantities                                      NaN                NaN
# Shipping times                                        NaN                NaN
# Shipping costs                                        NaN                NaN
# Lead time                                             NaN                NaN
# Production volumes                                    NaN                NaN
# Manufacturing lead time                               NaN                NaN
# Manufacturing costs                                   NaN                NaN
# Defect rates                                          NaN                NaN
# Costs                                                 NaN                NaN
# Product type_cosmetics                                NaN                NaN
# Product type_haircare                                 NaN                NaN
# Product type_skincare                                 NaN                NaN
# Customer demographics_Female                          NaN                NaN
# Customer demographics_Male                            NaN                NaN
# Customer demographics_Non-binary                      NaN                NaN
# Customer demographics_Unknown                         NaN                NaN
# Shipping carriers_Carrier A                           NaN                NaN
# Shipping carriers_Carrier B                           NaN                NaN
# Shipping carriers_Carrier C                           NaN                NaN
# Supplier name_Supplier 1                              NaN                NaN
# Supplier name_Supplier 2                              NaN                NaN
# Supplier name_Supplier 3                              NaN                NaN
# Supplier name_Supplier 4                              NaN                NaN
# Supplier name_Supplier 5                              NaN                NaN
# Location_Bangalore                                    NaN                NaN
# Location_Chennai                                      NaN                NaN
# Location_Delhi                                        NaN                NaN
# Location_Kolkata                                      NaN                NaN
# Location_Mumbai                                       NaN                NaN
# Location_Bangalore                                    NaN                NaN
# Location_Chennai                                      NaN                NaN
# Location_Delhi                                        NaN                NaN
# Location_Kolkata                                      NaN                NaN
# Location_Mumbai                                       NaN                NaN
# Inspection results_Fail                               NaN                NaN
# Inspection results_Pass                               NaN                NaN
# Inspection results_Pending                            NaN                NaN
# Transportation modes_Air                              NaN                NaN
# Transportation modes_Rail                             NaN                NaN
# Transportation modes_Road                             NaN                NaN
# Transportation modes_Sea                              NaN                NaN
# Routes_Route A                                        NaN                NaN
# Routes_Route B                                        NaN                NaN
# Routes_Route C                                        NaN                NaN
#
#                                   Stock levels  Lead times  Order quantities  \
# Price                                      NaN         NaN               NaN
# Availability                               NaN         NaN               NaN
# Number of products sold                    NaN         NaN               NaN
# Revenue generated                          NaN         NaN               NaN
# Stock levels                               NaN         NaN               NaN
# Lead times                                 NaN         NaN               NaN
# Order quantities                           NaN         NaN               NaN
# Shipping times                             NaN         NaN               NaN
# Shipping costs                             NaN         NaN               NaN
# Lead time                                  NaN         NaN               NaN
# Production volumes                         NaN         NaN               NaN
# Manufacturing lead time                    NaN         NaN               NaN
# Manufacturing costs                        NaN         NaN               NaN
# Defect rates                               NaN         NaN               NaN
# Costs                                      NaN         NaN               NaN
# Product type_cosmetics                     NaN         NaN               NaN
# Product type_haircare                      NaN         NaN               NaN
# Product type_skincare                      NaN         NaN               NaN
# Customer demographics_Female               NaN         NaN               NaN
# Customer demographics_Male                 NaN         NaN               NaN
# Customer demographics_Non-binary           NaN         NaN               NaN
# Customer demographics_Unknown              NaN         NaN               NaN
# Shipping carriers_Carrier A                NaN         NaN               NaN
# Shipping carriers_Carrier B                NaN         NaN               NaN
# Shipping carriers_Carrier C                NaN         NaN               NaN
# Supplier name_Supplier 1                   NaN         NaN               NaN
# Supplier name_Supplier 2                   NaN         NaN               NaN
# Supplier name_Supplier 3                   NaN         NaN               NaN
# Supplier name_Supplier 4                   NaN         NaN               NaN
# Supplier name_Supplier 5                   NaN         NaN               NaN
# Location_Bangalore                         NaN         NaN               NaN
# Location_Chennai                           NaN         NaN               NaN
# Location_Delhi                             NaN         NaN               NaN
# Location_Kolkata                           NaN         NaN               NaN
# Location_Mumbai                            NaN         NaN               NaN
# Location_Bangalore                         NaN         NaN               NaN
# Location_Chennai                           NaN         NaN               NaN
# Location_Delhi                             NaN         NaN               NaN
# Location_Kolkata                           NaN         NaN               NaN
# Location_Mumbai                            NaN         NaN               NaN
# Inspection results_Fail                    NaN         NaN               NaN
# Inspection results_Pass                    NaN         NaN               NaN
# Inspection results_Pending                 NaN         NaN               NaN
# Transportation modes_Air                   NaN         NaN               NaN
# Transportation modes_Rail                  NaN         NaN               NaN
# Transportation modes_Road                  NaN         NaN               NaN
# Transportation modes_Sea                   NaN         NaN               NaN
# Routes_Route A                             NaN         NaN               NaN
# Routes_Route B                             NaN         NaN               NaN
# Routes_Route C                             NaN         NaN               NaN
#
#                                   Shipping times  Shipping costs  Lead time  \
# Price                                        NaN             NaN        NaN
# Availability                                 NaN             NaN        NaN
# Number of products sold                      NaN             NaN        NaN
# Revenue generated                            NaN             NaN        NaN
# Stock levels                                 NaN             NaN        NaN
# Lead times                                   NaN             NaN        NaN
# Order quantities                             NaN             NaN        NaN
# Shipping times                               NaN             NaN        NaN
# Shipping costs                               NaN             NaN        NaN
# Lead time                                    NaN             NaN        NaN
# Production volumes                           NaN             NaN        NaN
# Manufacturing lead time                      NaN             NaN        NaN
# Manufacturing costs                          NaN             NaN        NaN
# Defect rates                                 NaN             NaN        NaN
# Costs                                        NaN             NaN        NaN
# Product type_cosmetics                       NaN             NaN        NaN
# Product type_haircare                        NaN             NaN        NaN
# Product type_skincare                        NaN             NaN        NaN
# Customer demographics_Female                 NaN             NaN        NaN
# Customer demographics_Male                   NaN             NaN        NaN
# Customer demographics_Non-binary             NaN             NaN        NaN
# Customer demographics_Unknown                NaN             NaN        NaN
# Shipping carriers_Carrier A                  NaN             NaN        NaN
# Shipping carriers_Carrier B                  NaN             NaN        NaN
# Shipping carriers_Carrier C                  NaN             NaN        NaN
# Supplier name_Supplier 1                     NaN             NaN        NaN
# Supplier name_Supplier 2                     NaN             NaN        NaN
# Supplier name_Supplier 3                     NaN             NaN        NaN
# Supplier name_Supplier 4                     NaN             NaN        NaN
# Supplier name_Supplier 5                     NaN             NaN        NaN
# Location_Bangalore                           NaN             NaN        NaN
# Location_Chennai                             NaN             NaN        NaN
# Location_Delhi                               NaN             NaN        NaN
# Location_Kolkata                             NaN             NaN        NaN
# Location_Mumbai                              NaN             NaN        NaN
# Location_Bangalore                           NaN             NaN        NaN
# Location_Chennai                             NaN             NaN        NaN
# Location_Delhi                               NaN             NaN        NaN
# Location_Kolkata                             NaN             NaN        NaN
# Location_Mumbai                              NaN             NaN        NaN
# Inspection results_Fail                      NaN             NaN        NaN
# Inspection results_Pass                      NaN             NaN        NaN
# Inspection results_Pending                   NaN             NaN        NaN
# Transportation modes_Air                     NaN             NaN        NaN
# Transportation modes_Rail                    NaN             NaN        NaN
# Transportation modes_Road                    NaN             NaN        NaN
# Transportation modes_Sea                     NaN             NaN        NaN
# Routes_Route A                               NaN             NaN        NaN
# Routes_Route B                               NaN             NaN        NaN
# Routes_Route C                               NaN             NaN        NaN
#
#                                   ...  Inspection results_Fail  \
# Price                             ...                      NaN
# Availability                      ...                      NaN
# Number of products sold           ...                      NaN
# Revenue generated                 ...                      NaN
# Stock levels                      ...                      NaN
# Lead times                        ...                      NaN
# Order quantities                  ...                      NaN
# Shipping times                    ...                      NaN
# Shipping costs                    ...                      NaN
# Lead time                         ...                      NaN
# Production volumes                ...                      NaN
# Manufacturing lead time           ...                      NaN
# Manufacturing costs               ...                      NaN
# Defect rates                      ...                      NaN
# Costs                             ...                      NaN
# Product type_cosmetics            ...                      NaN
# Product type_haircare             ...                      NaN
# Product type_skincare             ...                      NaN
# Customer demographics_Female      ...                      NaN
# Customer demographics_Male        ...                      NaN
# Customer demographics_Non-binary  ...                      NaN
# Customer demographics_Unknown     ...                      NaN
# Shipping carriers_Carrier A       ...                      NaN
# Shipping carriers_Carrier B       ...                      NaN
# Shipping carriers_Carrier C       ...                      NaN
# Supplier name_Supplier 1          ...                      NaN
# Supplier name_Supplier 2          ...                      NaN
# Supplier name_Supplier 3          ...                      NaN
# Supplier name_Supplier 4          ...                      NaN
# Supplier name_Supplier 5          ...                      NaN
# Location_Bangalore                ...                      NaN
# Location_Chennai                  ...                      NaN
# Location_Delhi                    ...                      NaN
# Location_Kolkata                  ...                      NaN
# Location_Mumbai                   ...                      NaN
# Location_Bangalore                ...                      NaN
# Location_Chennai                  ...                      NaN
# Location_Delhi                    ...                      NaN
# Location_Kolkata                  ...                      NaN
# Location_Mumbai                   ...                      NaN
# Inspection results_Fail           ...                      NaN
# Inspection results_Pass           ...                      NaN
# Inspection results_Pending        ...                -0.625212
# Transportation modes_Air          ...                      NaN
# Transportation modes_Rail         ...                      NaN
# Transportation modes_Road         ...                      NaN
# Transportation modes_Sea          ...                      NaN
# Routes_Route A                    ...                      NaN
# Routes_Route B                    ...                      NaN
# Routes_Route C                    ...                      NaN
#
#                                   Inspection results_Pass  \
# Price                                                 NaN
# Availability                                          NaN
# Number of products sold                               NaN
# Revenue generated                                     NaN
# Stock levels                                          NaN
# Lead times                                            NaN
# Order quantities                                      NaN
# Shipping times                                        NaN
# Shipping costs                                        NaN
# Lead time                                             NaN
# Production volumes                                    NaN
# Manufacturing lead time                               NaN
# Manufacturing costs                                   NaN
# Defect rates                                          NaN
# Costs                                                 NaN
# Product type_cosmetics                                NaN
# Product type_haircare                                 NaN
# Product type_skincare                                 NaN
# Customer demographics_Female                          NaN
# Customer demographics_Male                            NaN
# Customer demographics_Non-binary                      NaN
# Customer demographics_Unknown                         NaN
# Shipping carriers_Carrier A                           NaN
# Shipping carriers_Carrier B                           NaN
# Shipping carriers_Carrier C                           NaN
# Supplier name_Supplier 1                              NaN
# Supplier name_Supplier 2                              NaN
# Supplier name_Supplier 3                              NaN
# Supplier name_Supplier 4                              NaN
# Supplier name_Supplier 5                              NaN
# Location_Bangalore                                    NaN
# Location_Chennai                                      NaN
# Location_Delhi                                        NaN
# Location_Kolkata                                      NaN
# Location_Mumbai                                       NaN
# Location_Bangalore                                    NaN
# Location_Chennai                                      NaN
# Location_Delhi                                        NaN
# Location_Kolkata                                      NaN
# Location_Mumbai                                       NaN
# Inspection results_Fail                               NaN
# Inspection results_Pass                               NaN
# Inspection results_Pending                            NaN
# Transportation modes_Air                              NaN
# Transportation modes_Rail                             NaN
# Transportation modes_Road                             NaN
# Transportation modes_Sea                              NaN
# Routes_Route A                                        NaN
# Routes_Route B                                        NaN
# Routes_Route C                                        NaN
#
#                                   Inspection results_Pending  \
# Price                                                    NaN
# Availability                                             NaN
# Number of products sold                                  NaN
# Revenue generated                                        NaN
# Stock levels                                             NaN
# Lead times                                               NaN
# Order quantities                                         NaN
# Shipping times                                           NaN
# Shipping costs                                           NaN
# Lead time                                                NaN
# Production volumes                                       NaN
# Manufacturing lead time                                  NaN
# Manufacturing costs                                      NaN
# Defect rates                                             NaN
# Costs                                                    NaN
# Product type_cosmetics                                   NaN
# Product type_haircare                                    NaN
# Product type_skincare                                    NaN
# Customer demographics_Female                             NaN
# Customer demographics_Male                               NaN
# Customer demographics_Non-binary                         NaN
# Customer demographics_Unknown                            NaN
# Shipping carriers_Carrier A                              NaN
# Shipping carriers_Carrier B                              NaN
# Shipping carriers_Carrier C                              NaN
# Supplier name_Supplier 1                                 NaN
# Supplier name_Supplier 2                                 NaN
# Supplier name_Supplier 3                                 NaN
# Supplier name_Supplier 4                                 NaN
# Supplier name_Supplier 5                                 NaN
# Location_Bangalore                                       NaN
# Location_Chennai                                         NaN
# Location_Delhi                                           NaN
# Location_Kolkata                                         NaN
# Location_Mumbai                                          NaN
# Location_Bangalore                                       NaN
# Location_Chennai                                         NaN
# Location_Delhi                                           NaN
# Location_Kolkata                                         NaN
# Location_Mumbai                                          NaN
# Inspection results_Fail                            -0.625212
# Inspection results_Pass                                  NaN
# Inspection results_Pending                               NaN
# Transportation modes_Air                                 NaN
# Transportation modes_Rail                                NaN
# Transportation modes_Road                                NaN
# Transportation modes_Sea                                 NaN
# Routes_Route A                                           NaN
# Routes_Route B                                           NaN
# Routes_Route C                                           NaN
#
#                                   Transportation modes_Air  \
# Price                                                  NaN
# Availability                                           NaN
# Number of products sold                                NaN
# Revenue generated                                      NaN
# Stock levels                                           NaN
# Lead times                                             NaN
# Order quantities                                       NaN
# Shipping times                                         NaN
# Shipping costs                                         NaN
# Lead time                                              NaN
# Production volumes                                     NaN
# Manufacturing lead time                                NaN
# Manufacturing costs                                    NaN
# Defect rates                                           NaN
# Costs                                                  NaN
# Product type_cosmetics                                 NaN
# Product type_haircare                                  NaN
# Product type_skincare                                  NaN
# Customer demographics_Female                           NaN
# Customer demographics_Male                             NaN
# Customer demographics_Non-binary                       NaN
# Customer demographics_Unknown                          NaN
# Shipping carriers_Carrier A                            NaN
# Shipping carriers_Carrier B                            NaN
# Shipping carriers_Carrier C                            NaN
# Supplier name_Supplier 1                               NaN
# Supplier name_Supplier 2                               NaN
# Supplier name_Supplier 3                               NaN
# Supplier name_Supplier 4                               NaN
# Supplier name_Supplier 5                               NaN
# Location_Bangalore                                     NaN
# Location_Chennai                                       NaN
# Location_Delhi                                         NaN
# Location_Kolkata                                       NaN
# Location_Mumbai                                        NaN
# Location_Bangalore                                     NaN
# Location_Chennai                                       NaN
# Location_Delhi                                         NaN
# Location_Kolkata                                       NaN
# Location_Mumbai                                        NaN
# Inspection results_Fail                                NaN
# Inspection results_Pass                                NaN
# Inspection results_Pending                             NaN
# Transportation modes_Air                               NaN
# Transportation modes_Rail                              NaN
# Transportation modes_Road                              NaN
# Transportation modes_Sea                               NaN
# Routes_Route A                                         NaN
# Routes_Route B                                         NaN
# Routes_Route C                                         NaN
#
#                                   Transportation modes_Rail  \
# Price                                                   NaN
# Availability                                            NaN
# Number of products sold                                 NaN
# Revenue generated                                       NaN
# Stock levels                                            NaN
# Lead times                                              NaN
# Order quantities                                        NaN
# Shipping times                                          NaN
# Shipping costs                                          NaN
# Lead time                                               NaN
# Production volumes                                      NaN
# Manufacturing lead time                                 NaN
# Manufacturing costs                                     NaN
# Defect rates                                            NaN
# Costs                                                   NaN
# Product type_cosmetics                                  NaN
# Product type_haircare                                   NaN
# Product type_skincare                                   NaN
# Customer demographics_Female                            NaN
# Customer demographics_Male                              NaN
# Customer demographics_Non-binary                        NaN
# Customer demographics_Unknown                           NaN
# Shipping carriers_Carrier A                             NaN
# Shipping carriers_Carrier B                             NaN
# Shipping carriers_Carrier C                             NaN
# Supplier name_Supplier 1                                NaN
# Supplier name_Supplier 2                                NaN
# Supplier name_Supplier 3                                NaN
# Supplier name_Supplier 4                                NaN
# Supplier name_Supplier 5                                NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Inspection results_Fail                                 NaN
# Inspection results_Pass                                 NaN
# Inspection results_Pending                              NaN
# Transportation modes_Air                                NaN
# Transportation modes_Rail                               NaN
# Transportation modes_Road                               NaN
# Transportation modes_Sea                                NaN
# Routes_Route A                                          NaN
# Routes_Route B                                          NaN
# Routes_Route C                                          NaN
#
#                                   Transportation modes_Road  \
# Price                                                   NaN
# Availability                                            NaN
# Number of products sold                                 NaN
# Revenue generated                                       NaN
# Stock levels                                            NaN
# Lead times                                              NaN
# Order quantities                                        NaN
# Shipping times                                          NaN
# Shipping costs                                          NaN
# Lead time                                               NaN
# Production volumes                                      NaN
# Manufacturing lead time                                 NaN
# Manufacturing costs                                     NaN
# Defect rates                                            NaN
# Costs                                                   NaN
# Product type_cosmetics                                  NaN
# Product type_haircare                                   NaN
# Product type_skincare                                   NaN
# Customer demographics_Female                            NaN
# Customer demographics_Male                              NaN
# Customer demographics_Non-binary                        NaN
# Customer demographics_Unknown                           NaN
# Shipping carriers_Carrier A                             NaN
# Shipping carriers_Carrier B                             NaN
# Shipping carriers_Carrier C                             NaN
# Supplier name_Supplier 1                                NaN
# Supplier name_Supplier 2                                NaN
# Supplier name_Supplier 3                                NaN
# Supplier name_Supplier 4                                NaN
# Supplier name_Supplier 5                                NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Inspection results_Fail                                 NaN
# Inspection results_Pass                                 NaN
# Inspection results_Pending                              NaN
# Transportation modes_Air                                NaN
# Transportation modes_Rail                               NaN
# Transportation modes_Road                               NaN
# Transportation modes_Sea                                NaN
# Routes_Route A                                          NaN
# Routes_Route B                                          NaN
# Routes_Route C                                          NaN
#
#                                   Transportation modes_Sea  Routes_Route A  \
# Price                                                  NaN             NaN
# Availability                                           NaN             NaN
# Number of products sold                                NaN             NaN
# Revenue generated                                      NaN             NaN
# Stock levels                                           NaN             NaN
# Lead times                                             NaN             NaN
# Order quantities                                       NaN             NaN
# Shipping times                                         NaN             NaN
# Shipping costs                                         NaN             NaN
# Lead time                                              NaN             NaN
# Production volumes                                     NaN             NaN
# Manufacturing lead time                                NaN             NaN
# Manufacturing costs                                    NaN             NaN
# Defect rates                                           NaN             NaN
# Costs                                                  NaN             NaN
# Product type_cosmetics                                 NaN             NaN
# Product type_haircare                                  NaN             NaN
# Product type_skincare                                  NaN             NaN
# Customer demographics_Female                           NaN             NaN
# Customer demographics_Male                             NaN             NaN
# Customer demographics_Non-binary                       NaN             NaN
# Customer demographics_Unknown                          NaN             NaN
# Shipping carriers_Carrier A                            NaN             NaN
# Shipping carriers_Carrier B                            NaN             NaN
# Shipping carriers_Carrier C                            NaN             NaN
# Supplier name_Supplier 1                               NaN             NaN
# Supplier name_Supplier 2                               NaN             NaN
# Supplier name_Supplier 3                               NaN             NaN
# Supplier name_Supplier 4                               NaN             NaN
# Supplier name_Supplier 5                               NaN             NaN
# Location_Bangalore                                     NaN             NaN
# Location_Chennai                                       NaN             NaN
# Location_Delhi                                         NaN             NaN
# Location_Kolkata                                       NaN             NaN
# Location_Mumbai                                        NaN             NaN
# Location_Bangalore                                     NaN             NaN
# Location_Chennai                                       NaN             NaN
# Location_Delhi                                         NaN             NaN
# Location_Kolkata                                       NaN             NaN
# Location_Mumbai                                        NaN             NaN
# Inspection results_Fail                                NaN             NaN
# Inspection results_Pass                                NaN             NaN
# Inspection results_Pending                             NaN             NaN
# Transportation modes_Air                               NaN             NaN
# Transportation modes_Rail                              NaN             NaN
# Transportation modes_Road                              NaN             NaN
# Transportation modes_Sea                               NaN             NaN
# Routes_Route A                                         NaN             NaN
# Routes_Route B                                         NaN       -0.665622
# Routes_Route C                                         NaN             NaN
#
#                                   Routes_Route B  Routes_Route C
# Price                                        NaN             NaN
# Availability                                 NaN             NaN
# Number of products sold                      NaN             NaN
# Revenue generated                            NaN             NaN
# Stock levels                                 NaN             NaN
# Lead times                                   NaN             NaN
# Order quantities                             NaN             NaN
# Shipping times                               NaN             NaN
# Shipping costs                               NaN             NaN
# Lead time                                    NaN             NaN
# Production volumes                           NaN             NaN
# Manufacturing lead time                      NaN             NaN
# Manufacturing costs                          NaN             NaN
# Defect rates                                 NaN             NaN
# Costs                                        NaN             NaN
# Product type_cosmetics                       NaN             NaN
# Product type_haircare                        NaN             NaN
# Product type_skincare                        NaN             NaN
# Customer demographics_Female                 NaN             NaN
# Customer demographics_Male                   NaN             NaN
# Customer demographics_Non-binary             NaN             NaN
# Customer demographics_Unknown                NaN             NaN
# Shipping carriers_Carrier A                  NaN             NaN
# Shipping carriers_Carrier B                  NaN             NaN
# Shipping carriers_Carrier C                  NaN             NaN
# Supplier name_Supplier 1                     NaN             NaN
# Supplier name_Supplier 2                     NaN             NaN
# Supplier name_Supplier 3                     NaN             NaN
# Supplier name_Supplier 4                     NaN             NaN
# Supplier name_Supplier 5                     NaN             NaN
# Location_Bangalore                           NaN             NaN
# Location_Chennai                             NaN             NaN
# Location_Delhi                               NaN             NaN
# Location_Kolkata                             NaN             NaN
# Location_Mumbai                              NaN             NaN
# Location_Bangalore                           NaN             NaN
# Location_Chennai                             NaN             NaN
# Location_Delhi                               NaN             NaN
# Location_Kolkata                             NaN             NaN
# Location_Mumbai                              NaN             NaN
# Inspection results_Fail                      NaN             NaN
# Inspection results_Pass                      NaN             NaN
# Inspection results_Pending                   NaN             NaN
# Transportation modes_Air                     NaN             NaN
# Transportation modes_Rail                    NaN             NaN
# Transportation modes_Road                    NaN             NaN
# Transportation modes_Sea                     NaN             NaN
# Routes_Route A                         -0.665622             NaN
# Routes_Route B                               NaN             NaN
# Routes_Route C                               NaN             NaN
#
# [50 rows x 50 columns]

# %% [markdown]
# We can conclude that there are no linear relationships between features in the dataset

# %%
 matrix_spearman = df2.drop(columns=['SKU']).corr(method='spearman')

# %%
filtered_values_spearman = matrix_spearman[
    (matrix >= 0.5) & (matrix < 1) |
    (matrix <= -0.5) & (matrix > -1)
]
print(filtered_values_spearman)
# Out:
#                                   Price  Availability  \
# Price                               NaN           NaN
# Availability                        NaN           NaN
# Number of products sold             NaN           NaN
# Revenue generated                   NaN           NaN
# Stock levels                        NaN           NaN
# Lead times                          NaN           NaN
# Order quantities                    NaN           NaN
# Shipping times                      NaN           NaN
# Shipping costs                      NaN           NaN
# Lead time                           NaN           NaN
# Production volumes                  NaN           NaN
# Manufacturing lead time             NaN           NaN
# Manufacturing costs                 NaN           NaN
# Defect rates                        NaN           NaN
# Costs                               NaN           NaN
# Product type_cosmetics              NaN           NaN
# Product type_haircare               NaN           NaN
# Product type_skincare               NaN           NaN
# Customer demographics_Female        NaN           NaN
# Customer demographics_Male          NaN           NaN
# Customer demographics_Non-binary    NaN           NaN
# Customer demographics_Unknown       NaN           NaN
# Shipping carriers_Carrier A         NaN           NaN
# Shipping carriers_Carrier B         NaN           NaN
# Shipping carriers_Carrier C         NaN           NaN
# Supplier name_Supplier 1            NaN           NaN
# Supplier name_Supplier 2            NaN           NaN
# Supplier name_Supplier 3            NaN           NaN
# Supplier name_Supplier 4            NaN           NaN
# Supplier name_Supplier 5            NaN           NaN
# Location_Bangalore                  NaN           NaN
# Location_Chennai                    NaN           NaN
# Location_Delhi                      NaN           NaN
# Location_Kolkata                    NaN           NaN
# Location_Mumbai                     NaN           NaN
# Location_Bangalore                  NaN           NaN
# Location_Chennai                    NaN           NaN
# Location_Delhi                      NaN           NaN
# Location_Kolkata                    NaN           NaN
# Location_Mumbai                     NaN           NaN
# Inspection results_Fail             NaN           NaN
# Inspection results_Pass             NaN           NaN
# Inspection results_Pending          NaN           NaN
# Transportation modes_Air            NaN           NaN
# Transportation modes_Rail           NaN           NaN
# Transportation modes_Road           NaN           NaN
# Transportation modes_Sea            NaN           NaN
# Routes_Route A                      NaN           NaN
# Routes_Route B                      NaN           NaN
# Routes_Route C                      NaN           NaN
#
#                                   Number of products sold  Revenue generated  \
# Price                                                 NaN                NaN
# Availability                                          NaN                NaN
# Number of products sold                               NaN                NaN
# Revenue generated                                     NaN                NaN
# Stock levels                                          NaN                NaN
# Lead times                                            NaN                NaN
# Order quantities                                      NaN                NaN
# Shipping times                                        NaN                NaN
# Shipping costs                                        NaN                NaN
# Lead time                                             NaN                NaN
# Production volumes                                    NaN                NaN
# Manufacturing lead time                               NaN                NaN
# Manufacturing costs                                   NaN                NaN
# Defect rates                                          NaN                NaN
# Costs                                                 NaN                NaN
# Product type_cosmetics                                NaN                NaN
# Product type_haircare                                 NaN                NaN
# Product type_skincare                                 NaN                NaN
# Customer demographics_Female                          NaN                NaN
# Customer demographics_Male                            NaN                NaN
# Customer demographics_Non-binary                      NaN                NaN
# Customer demographics_Unknown                         NaN                NaN
# Shipping carriers_Carrier A                           NaN                NaN
# Shipping carriers_Carrier B                           NaN                NaN
# Shipping carriers_Carrier C                           NaN                NaN
# Supplier name_Supplier 1                              NaN                NaN
# Supplier name_Supplier 2                              NaN                NaN
# Supplier name_Supplier 3                              NaN                NaN
# Supplier name_Supplier 4                              NaN                NaN
# Supplier name_Supplier 5                              NaN                NaN
# Location_Bangalore                                    NaN                NaN
# Location_Chennai                                      NaN                NaN
# Location_Delhi                                        NaN                NaN
# Location_Kolkata                                      NaN                NaN
# Location_Mumbai                                       NaN                NaN
# Location_Bangalore                                    NaN                NaN
# Location_Chennai                                      NaN                NaN
# Location_Delhi                                        NaN                NaN
# Location_Kolkata                                      NaN                NaN
# Location_Mumbai                                       NaN                NaN
# Inspection results_Fail                               NaN                NaN
# Inspection results_Pass                               NaN                NaN
# Inspection results_Pending                            NaN                NaN
# Transportation modes_Air                              NaN                NaN
# Transportation modes_Rail                             NaN                NaN
# Transportation modes_Road                             NaN                NaN
# Transportation modes_Sea                              NaN                NaN
# Routes_Route A                                        NaN                NaN
# Routes_Route B                                        NaN                NaN
# Routes_Route C                                        NaN                NaN
#
#                                   Stock levels  Lead times  Order quantities  \
# Price                                      NaN         NaN               NaN
# Availability                               NaN         NaN               NaN
# Number of products sold                    NaN         NaN               NaN
# Revenue generated                          NaN         NaN               NaN
# Stock levels                               NaN         NaN               NaN
# Lead times                                 NaN         NaN               NaN
# Order quantities                           NaN         NaN               NaN
# Shipping times                             NaN         NaN               NaN
# Shipping costs                             NaN         NaN               NaN
# Lead time                                  NaN         NaN               NaN
# Production volumes                         NaN         NaN               NaN
# Manufacturing lead time                    NaN         NaN               NaN
# Manufacturing costs                        NaN         NaN               NaN
# Defect rates                               NaN         NaN               NaN
# Costs                                      NaN         NaN               NaN
# Product type_cosmetics                     NaN         NaN               NaN
# Product type_haircare                      NaN         NaN               NaN
# Product type_skincare                      NaN         NaN               NaN
# Customer demographics_Female               NaN         NaN               NaN
# Customer demographics_Male                 NaN         NaN               NaN
# Customer demographics_Non-binary           NaN         NaN               NaN
# Customer demographics_Unknown              NaN         NaN               NaN
# Shipping carriers_Carrier A                NaN         NaN               NaN
# Shipping carriers_Carrier B                NaN         NaN               NaN
# Shipping carriers_Carrier C                NaN         NaN               NaN
# Supplier name_Supplier 1                   NaN         NaN               NaN
# Supplier name_Supplier 2                   NaN         NaN               NaN
# Supplier name_Supplier 3                   NaN         NaN               NaN
# Supplier name_Supplier 4                   NaN         NaN               NaN
# Supplier name_Supplier 5                   NaN         NaN               NaN
# Location_Bangalore                         NaN         NaN               NaN
# Location_Chennai                           NaN         NaN               NaN
# Location_Delhi                             NaN         NaN               NaN
# Location_Kolkata                           NaN         NaN               NaN
# Location_Mumbai                            NaN         NaN               NaN
# Location_Bangalore                         NaN         NaN               NaN
# Location_Chennai                           NaN         NaN               NaN
# Location_Delhi                             NaN         NaN               NaN
# Location_Kolkata                           NaN         NaN               NaN
# Location_Mumbai                            NaN         NaN               NaN
# Inspection results_Fail                    NaN         NaN               NaN
# Inspection results_Pass                    NaN         NaN               NaN
# Inspection results_Pending                 NaN         NaN               NaN
# Transportation modes_Air                   NaN         NaN               NaN
# Transportation modes_Rail                  NaN         NaN               NaN
# Transportation modes_Road                  NaN         NaN               NaN
# Transportation modes_Sea                   NaN         NaN               NaN
# Routes_Route A                             NaN         NaN               NaN
# Routes_Route B                             NaN         NaN               NaN
# Routes_Route C                             NaN         NaN               NaN
#
#                                   Shipping times  Shipping costs  Lead time  \
# Price                                        NaN             NaN        NaN
# Availability                                 NaN             NaN        NaN
# Number of products sold                      NaN             NaN        NaN
# Revenue generated                            NaN             NaN        NaN
# Stock levels                                 NaN             NaN        NaN
# Lead times                                   NaN             NaN        NaN
# Order quantities                             NaN             NaN        NaN
# Shipping times                               NaN             NaN        NaN
# Shipping costs                               NaN             NaN        NaN
# Lead time                                    NaN             NaN        NaN
# Production volumes                           NaN             NaN        NaN
# Manufacturing lead time                      NaN             NaN        NaN
# Manufacturing costs                          NaN             NaN        NaN
# Defect rates                                 NaN             NaN        NaN
# Costs                                        NaN             NaN        NaN
# Product type_cosmetics                       NaN             NaN        NaN
# Product type_haircare                        NaN             NaN        NaN
# Product type_skincare                        NaN             NaN        NaN
# Customer demographics_Female                 NaN             NaN        NaN
# Customer demographics_Male                   NaN             NaN        NaN
# Customer demographics_Non-binary             NaN             NaN        NaN
# Customer demographics_Unknown                NaN             NaN        NaN
# Shipping carriers_Carrier A                  NaN             NaN        NaN
# Shipping carriers_Carrier B                  NaN             NaN        NaN
# Shipping carriers_Carrier C                  NaN             NaN        NaN
# Supplier name_Supplier 1                     NaN             NaN        NaN
# Supplier name_Supplier 2                     NaN             NaN        NaN
# Supplier name_Supplier 3                     NaN             NaN        NaN
# Supplier name_Supplier 4                     NaN             NaN        NaN
# Supplier name_Supplier 5                     NaN             NaN        NaN
# Location_Bangalore                           NaN             NaN        NaN
# Location_Chennai                             NaN             NaN        NaN
# Location_Delhi                               NaN             NaN        NaN
# Location_Kolkata                             NaN             NaN        NaN
# Location_Mumbai                              NaN             NaN        NaN
# Location_Bangalore                           NaN             NaN        NaN
# Location_Chennai                             NaN             NaN        NaN
# Location_Delhi                               NaN             NaN        NaN
# Location_Kolkata                             NaN             NaN        NaN
# Location_Mumbai                              NaN             NaN        NaN
# Inspection results_Fail                      NaN             NaN        NaN
# Inspection results_Pass                      NaN             NaN        NaN
# Inspection results_Pending                   NaN             NaN        NaN
# Transportation modes_Air                     NaN             NaN        NaN
# Transportation modes_Rail                    NaN             NaN        NaN
# Transportation modes_Road                    NaN             NaN        NaN
# Transportation modes_Sea                     NaN             NaN        NaN
# Routes_Route A                               NaN             NaN        NaN
# Routes_Route B                               NaN             NaN        NaN
# Routes_Route C                               NaN             NaN        NaN
#
#                                   ...  Inspection results_Fail  \
# Price                             ...                      NaN
# Availability                      ...                      NaN
# Number of products sold           ...                      NaN
# Revenue generated                 ...                      NaN
# Stock levels                      ...                      NaN
# Lead times                        ...                      NaN
# Order quantities                  ...                      NaN
# Shipping times                    ...                      NaN
# Shipping costs                    ...                      NaN
# Lead time                         ...                      NaN
# Production volumes                ...                      NaN
# Manufacturing lead time           ...                      NaN
# Manufacturing costs               ...                      NaN
# Defect rates                      ...                      NaN
# Costs                             ...                      NaN
# Product type_cosmetics            ...                      NaN
# Product type_haircare             ...                      NaN
# Product type_skincare             ...                      NaN
# Customer demographics_Female      ...                      NaN
# Customer demographics_Male        ...                      NaN
# Customer demographics_Non-binary  ...                      NaN
# Customer demographics_Unknown     ...                      NaN
# Shipping carriers_Carrier A       ...                      NaN
# Shipping carriers_Carrier B       ...                      NaN
# Shipping carriers_Carrier C       ...                      NaN
# Supplier name_Supplier 1          ...                      NaN
# Supplier name_Supplier 2          ...                      NaN
# Supplier name_Supplier 3          ...                      NaN
# Supplier name_Supplier 4          ...                      NaN
# Supplier name_Supplier 5          ...                      NaN
# Location_Bangalore                ...                      NaN
# Location_Chennai                  ...                      NaN
# Location_Delhi                    ...                      NaN
# Location_Kolkata                  ...                      NaN
# Location_Mumbai                   ...                      NaN
# Location_Bangalore                ...                      NaN
# Location_Chennai                  ...                      NaN
# Location_Delhi                    ...                      NaN
# Location_Kolkata                  ...                      NaN
# Location_Mumbai                   ...                      NaN
# Inspection results_Fail           ...                      NaN
# Inspection results_Pass           ...                      NaN
# Inspection results_Pending        ...                -0.625212
# Transportation modes_Air          ...                      NaN
# Transportation modes_Rail         ...                      NaN
# Transportation modes_Road         ...                      NaN
# Transportation modes_Sea          ...                      NaN
# Routes_Route A                    ...                      NaN
# Routes_Route B                    ...                      NaN
# Routes_Route C                    ...                      NaN
#
#                                   Inspection results_Pass  \
# Price                                                 NaN
# Availability                                          NaN
# Number of products sold                               NaN
# Revenue generated                                     NaN
# Stock levels                                          NaN
# Lead times                                            NaN
# Order quantities                                      NaN
# Shipping times                                        NaN
# Shipping costs                                        NaN
# Lead time                                             NaN
# Production volumes                                    NaN
# Manufacturing lead time                               NaN
# Manufacturing costs                                   NaN
# Defect rates                                          NaN
# Costs                                                 NaN
# Product type_cosmetics                                NaN
# Product type_haircare                                 NaN
# Product type_skincare                                 NaN
# Customer demographics_Female                          NaN
# Customer demographics_Male                            NaN
# Customer demographics_Non-binary                      NaN
# Customer demographics_Unknown                         NaN
# Shipping carriers_Carrier A                           NaN
# Shipping carriers_Carrier B                           NaN
# Shipping carriers_Carrier C                           NaN
# Supplier name_Supplier 1                              NaN
# Supplier name_Supplier 2                              NaN
# Supplier name_Supplier 3                              NaN
# Supplier name_Supplier 4                              NaN
# Supplier name_Supplier 5                              NaN
# Location_Bangalore                                    NaN
# Location_Chennai                                      NaN
# Location_Delhi                                        NaN
# Location_Kolkata                                      NaN
# Location_Mumbai                                       NaN
# Location_Bangalore                                    NaN
# Location_Chennai                                      NaN
# Location_Delhi                                        NaN
# Location_Kolkata                                      NaN
# Location_Mumbai                                       NaN
# Inspection results_Fail                               NaN
# Inspection results_Pass                               NaN
# Inspection results_Pending                            NaN
# Transportation modes_Air                              NaN
# Transportation modes_Rail                             NaN
# Transportation modes_Road                             NaN
# Transportation modes_Sea                              NaN
# Routes_Route A                                        NaN
# Routes_Route B                                        NaN
# Routes_Route C                                        NaN
#
#                                   Inspection results_Pending  \
# Price                                                    NaN
# Availability                                             NaN
# Number of products sold                                  NaN
# Revenue generated                                        NaN
# Stock levels                                             NaN
# Lead times                                               NaN
# Order quantities                                         NaN
# Shipping times                                           NaN
# Shipping costs                                           NaN
# Lead time                                                NaN
# Production volumes                                       NaN
# Manufacturing lead time                                  NaN
# Manufacturing costs                                      NaN
# Defect rates                                             NaN
# Costs                                                    NaN
# Product type_cosmetics                                   NaN
# Product type_haircare                                    NaN
# Product type_skincare                                    NaN
# Customer demographics_Female                             NaN
# Customer demographics_Male                               NaN
# Customer demographics_Non-binary                         NaN
# Customer demographics_Unknown                            NaN
# Shipping carriers_Carrier A                              NaN
# Shipping carriers_Carrier B                              NaN
# Shipping carriers_Carrier C                              NaN
# Supplier name_Supplier 1                                 NaN
# Supplier name_Supplier 2                                 NaN
# Supplier name_Supplier 3                                 NaN
# Supplier name_Supplier 4                                 NaN
# Supplier name_Supplier 5                                 NaN
# Location_Bangalore                                       NaN
# Location_Chennai                                         NaN
# Location_Delhi                                           NaN
# Location_Kolkata                                         NaN
# Location_Mumbai                                          NaN
# Location_Bangalore                                       NaN
# Location_Chennai                                         NaN
# Location_Delhi                                           NaN
# Location_Kolkata                                         NaN
# Location_Mumbai                                          NaN
# Inspection results_Fail                            -0.625212
# Inspection results_Pass                                  NaN
# Inspection results_Pending                               NaN
# Transportation modes_Air                                 NaN
# Transportation modes_Rail                                NaN
# Transportation modes_Road                                NaN
# Transportation modes_Sea                                 NaN
# Routes_Route A                                           NaN
# Routes_Route B                                           NaN
# Routes_Route C                                           NaN
#
#                                   Transportation modes_Air  \
# Price                                                  NaN
# Availability                                           NaN
# Number of products sold                                NaN
# Revenue generated                                      NaN
# Stock levels                                           NaN
# Lead times                                             NaN
# Order quantities                                       NaN
# Shipping times                                         NaN
# Shipping costs                                         NaN
# Lead time                                              NaN
# Production volumes                                     NaN
# Manufacturing lead time                                NaN
# Manufacturing costs                                    NaN
# Defect rates                                           NaN
# Costs                                                  NaN
# Product type_cosmetics                                 NaN
# Product type_haircare                                  NaN
# Product type_skincare                                  NaN
# Customer demographics_Female                           NaN
# Customer demographics_Male                             NaN
# Customer demographics_Non-binary                       NaN
# Customer demographics_Unknown                          NaN
# Shipping carriers_Carrier A                            NaN
# Shipping carriers_Carrier B                            NaN
# Shipping carriers_Carrier C                            NaN
# Supplier name_Supplier 1                               NaN
# Supplier name_Supplier 2                               NaN
# Supplier name_Supplier 3                               NaN
# Supplier name_Supplier 4                               NaN
# Supplier name_Supplier 5                               NaN
# Location_Bangalore                                     NaN
# Location_Chennai                                       NaN
# Location_Delhi                                         NaN
# Location_Kolkata                                       NaN
# Location_Mumbai                                        NaN
# Location_Bangalore                                     NaN
# Location_Chennai                                       NaN
# Location_Delhi                                         NaN
# Location_Kolkata                                       NaN
# Location_Mumbai                                        NaN
# Inspection results_Fail                                NaN
# Inspection results_Pass                                NaN
# Inspection results_Pending                             NaN
# Transportation modes_Air                               NaN
# Transportation modes_Rail                              NaN
# Transportation modes_Road                              NaN
# Transportation modes_Sea                               NaN
# Routes_Route A                                         NaN
# Routes_Route B                                         NaN
# Routes_Route C                                         NaN
#
#                                   Transportation modes_Rail  \
# Price                                                   NaN
# Availability                                            NaN
# Number of products sold                                 NaN
# Revenue generated                                       NaN
# Stock levels                                            NaN
# Lead times                                              NaN
# Order quantities                                        NaN
# Shipping times                                          NaN
# Shipping costs                                          NaN
# Lead time                                               NaN
# Production volumes                                      NaN
# Manufacturing lead time                                 NaN
# Manufacturing costs                                     NaN
# Defect rates                                            NaN
# Costs                                                   NaN
# Product type_cosmetics                                  NaN
# Product type_haircare                                   NaN
# Product type_skincare                                   NaN
# Customer demographics_Female                            NaN
# Customer demographics_Male                              NaN
# Customer demographics_Non-binary                        NaN
# Customer demographics_Unknown                           NaN
# Shipping carriers_Carrier A                             NaN
# Shipping carriers_Carrier B                             NaN
# Shipping carriers_Carrier C                             NaN
# Supplier name_Supplier 1                                NaN
# Supplier name_Supplier 2                                NaN
# Supplier name_Supplier 3                                NaN
# Supplier name_Supplier 4                                NaN
# Supplier name_Supplier 5                                NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Inspection results_Fail                                 NaN
# Inspection results_Pass                                 NaN
# Inspection results_Pending                              NaN
# Transportation modes_Air                                NaN
# Transportation modes_Rail                               NaN
# Transportation modes_Road                               NaN
# Transportation modes_Sea                                NaN
# Routes_Route A                                          NaN
# Routes_Route B                                          NaN
# Routes_Route C                                          NaN
#
#                                   Transportation modes_Road  \
# Price                                                   NaN
# Availability                                            NaN
# Number of products sold                                 NaN
# Revenue generated                                       NaN
# Stock levels                                            NaN
# Lead times                                              NaN
# Order quantities                                        NaN
# Shipping times                                          NaN
# Shipping costs                                          NaN
# Lead time                                               NaN
# Production volumes                                      NaN
# Manufacturing lead time                                 NaN
# Manufacturing costs                                     NaN
# Defect rates                                            NaN
# Costs                                                   NaN
# Product type_cosmetics                                  NaN
# Product type_haircare                                   NaN
# Product type_skincare                                   NaN
# Customer demographics_Female                            NaN
# Customer demographics_Male                              NaN
# Customer demographics_Non-binary                        NaN
# Customer demographics_Unknown                           NaN
# Shipping carriers_Carrier A                             NaN
# Shipping carriers_Carrier B                             NaN
# Shipping carriers_Carrier C                             NaN
# Supplier name_Supplier 1                                NaN
# Supplier name_Supplier 2                                NaN
# Supplier name_Supplier 3                                NaN
# Supplier name_Supplier 4                                NaN
# Supplier name_Supplier 5                                NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Location_Bangalore                                      NaN
# Location_Chennai                                        NaN
# Location_Delhi                                          NaN
# Location_Kolkata                                        NaN
# Location_Mumbai                                         NaN
# Inspection results_Fail                                 NaN
# Inspection results_Pass                                 NaN
# Inspection results_Pending                              NaN
# Transportation modes_Air                                NaN
# Transportation modes_Rail                               NaN
# Transportation modes_Road                               NaN
# Transportation modes_Sea                                NaN
# Routes_Route A                                          NaN
# Routes_Route B                                          NaN
# Routes_Route C                                          NaN
#
#                                   Transportation modes_Sea  Routes_Route A  \
# Price                                                  NaN             NaN
# Availability                                           NaN             NaN
# Number of products sold                                NaN             NaN
# Revenue generated                                      NaN             NaN
# Stock levels                                           NaN             NaN
# Lead times                                             NaN             NaN
# Order quantities                                       NaN             NaN
# Shipping times                                         NaN             NaN
# Shipping costs                                         NaN             NaN
# Lead time                                              NaN             NaN
# Production volumes                                     NaN             NaN
# Manufacturing lead time                                NaN             NaN
# Manufacturing costs                                    NaN             NaN
# Defect rates                                           NaN             NaN
# Costs                                                  NaN             NaN
# Product type_cosmetics                                 NaN             NaN
# Product type_haircare                                  NaN             NaN
# Product type_skincare                                  NaN             NaN
# Customer demographics_Female                           NaN             NaN
# Customer demographics_Male                             NaN             NaN
# Customer demographics_Non-binary                       NaN             NaN
# Customer demographics_Unknown                          NaN             NaN
# Shipping carriers_Carrier A                            NaN             NaN
# Shipping carriers_Carrier B                            NaN             NaN
# Shipping carriers_Carrier C                            NaN             NaN
# Supplier name_Supplier 1                               NaN             NaN
# Supplier name_Supplier 2                               NaN             NaN
# Supplier name_Supplier 3                               NaN             NaN
# Supplier name_Supplier 4                               NaN             NaN
# Supplier name_Supplier 5                               NaN             NaN
# Location_Bangalore                                     NaN             NaN
# Location_Chennai                                       NaN             NaN
# Location_Delhi                                         NaN             NaN
# Location_Kolkata                                       NaN             NaN
# Location_Mumbai                                        NaN             NaN
# Location_Bangalore                                     NaN             NaN
# Location_Chennai                                       NaN             NaN
# Location_Delhi                                         NaN             NaN
# Location_Kolkata                                       NaN             NaN
# Location_Mumbai                                        NaN             NaN
# Inspection results_Fail                                NaN             NaN
# Inspection results_Pass                                NaN             NaN
# Inspection results_Pending                             NaN             NaN
# Transportation modes_Air                               NaN             NaN
# Transportation modes_Rail                              NaN             NaN
# Transportation modes_Road                              NaN             NaN
# Transportation modes_Sea                               NaN             NaN
# Routes_Route A                                         NaN             NaN
# Routes_Route B                                         NaN       -0.665622
# Routes_Route C                                         NaN             NaN
#
#                                   Routes_Route B  Routes_Route C
# Price                                        NaN             NaN
# Availability                                 NaN             NaN
# Number of products sold                      NaN             NaN
# Revenue generated                            NaN             NaN
# Stock levels                                 NaN             NaN
# Lead times                                   NaN             NaN
# Order quantities                             NaN             NaN
# Shipping times                               NaN             NaN
# Shipping costs                               NaN             NaN
# Lead time                                    NaN             NaN
# Production volumes                           NaN             NaN
# Manufacturing lead time                      NaN             NaN
# Manufacturing costs                          NaN             NaN
# Defect rates                                 NaN             NaN
# Costs                                        NaN             NaN
# Product type_cosmetics                       NaN             NaN
# Product type_haircare                        NaN             NaN
# Product type_skincare                        NaN             NaN
# Customer demographics_Female                 NaN             NaN
# Customer demographics_Male                   NaN             NaN
# Customer demographics_Non-binary             NaN             NaN
# Customer demographics_Unknown                NaN             NaN
# Shipping carriers_Carrier A                  NaN             NaN
# Shipping carriers_Carrier B                  NaN             NaN
# Shipping carriers_Carrier C                  NaN             NaN
# Supplier name_Supplier 1                     NaN             NaN
# Supplier name_Supplier 2                     NaN             NaN
# Supplier name_Supplier 3                     NaN             NaN
# Supplier name_Supplier 4                     NaN             NaN
# Supplier name_Supplier 5                     NaN             NaN
# Location_Bangalore                           NaN             NaN
# Location_Chennai                             NaN             NaN
# Location_Delhi                               NaN             NaN
# Location_Kolkata                             NaN             NaN
# Location_Mumbai                              NaN             NaN
# Location_Bangalore                           NaN             NaN
# Location_Chennai                             NaN             NaN
# Location_Delhi                               NaN             NaN
# Location_Kolkata                             NaN             NaN
# Location_Mumbai                              NaN             NaN
# Inspection results_Fail                      NaN             NaN
# Inspection results_Pass                      NaN             NaN
# Inspection results_Pending                   NaN             NaN
# Transportation modes_Air                     NaN             NaN
# Transportation modes_Rail                    NaN             NaN
# Transportation modes_Road                    NaN             NaN
# Transportation modes_Sea                     NaN             NaN
# Routes_Route A                         -0.665622             NaN
# Routes_Route B                               NaN             NaN
# Routes_Route C                               NaN             NaN
#
# [50 rows x 50 columns]

# %% [markdown]
# We can conclude that there is no monotonic relationship between the features

# %%
df.groupby('Location')['Order quantities'].sum().plot(kind='bar')
plt.xlabel('City')
plt.ylabel('Frequency')
plt.title('Product Quantities Sold by Location')
plt.show()

# %% [markdown]
# We can find quantities sold per city from the above bar chart

# %%
product_types = df[df['Customer demographics'] != 'Unknown'].groupby(['Product type', 'Customer demographics']).size().unstack()
plt.style.use('ggplot')
product_types.plot(kind='pie', subplots=True, figsize=(20, 10), autopct='%1.1f%%')
plt.title('Distribution of Product Types by Customer Demographics', fontsize = 22)
plt.show()

# %% [markdown]
# From the above pie chart we can conclude that the female customers are the most interested in skin care and cosmetic products while the male customers are majorly interested in haircare products and the non-binaries are interested in skincare the most.

# %%
df.groupby('Supplier name')['Defect rates'].mean().plot(kind='bar', color='blue')
plt.xlabel('Supplier Name')
plt.ylabel('Defect Rates Average')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# From the above bar graph we can conclude that Supplier 5 has the highest average defect rates and Supplier 1 has the lowest

# %%
df.groupby(['Routes', 'Transportation modes'])['Order quantities'].sum().unstack().plot(kind='bar')
plt.xlabel('Routes')
plt.ylabel('Order Quantities')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# The stacked bar chart depicts the distribution of order quantities across different routes, segmented by transportation modes.

# %%
df.groupby(['Supplier name','Product type'])['Lead time'].mean().unstack().plot(kind='bar')
plt.xlabel('Supplier Name')
plt.ylabel('Average Lead Time')
plt.xticks(rotation=45)
plt.title('Average Lead Time by Supplier and Product Type')
plt.show()

# %% [markdown]
# The above graph can be used to find out the average lead time for each supplier by product type and can also be used to conclude which type of products on an average take the most time.

# %%
boxplot_data = []

for product_type, data in product_types.iterrows():
    manufacturing_costs = df[df['Product type'] == product_type]['Manufacturing costs']
    boxplot_data.append(manufacturing_costs)

plt.boxplot(boxplot_data, labels=product_types.index)
plt.xlabel('Product Type')
plt.ylabel('Manufacturing Cost')
plt.title('Box and Whiskers Chart for Manufacturing Cost by Product Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Distribution of Manufacturing cost per product type

# %%
boxplot_data = []

for product_type, data in product_types.iterrows():
    costs = df[df['Product type'] == product_type]['Costs']
    boxplot_data.append(costs)

plt.boxplot(boxplot_data, labels=product_types.index)
plt.xlabel('Product Type')
plt.ylabel('Costs')
plt.title('Box and Whiskers Chart for Costs by Product Type')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Distribution of Product cost per product type

# %%
carriers = df['Shipping carriers'].unique()
for carrier in carriers:
    carrier_data = df[df['Shipping carriers'] == carrier]
    plt.scatter(carrier_data['Order quantities'], carrier_data['Shipping costs'], label=carrier)
    plt.title(f'Shipping Costs vs. Order Quantities for {carrier}')
    plt.xlabel('Order Quantities')
    plt.ylabel('Shipping Costs')
    plt.show()

# %% [markdown]
# From the above scatter plots we can find out the shipping costs for each order quantity for each carrier.

# %%
revenue_by_demographics = df[df['Customer demographics']!='Unknown'].groupby('Customer demographics')['Revenue generated'].sum()
plt.figure(figsize=(4, 4))
plt.pie(revenue_by_demographics, labels=revenue_by_demographics.index, autopct='%1.1f%%')
plt.title('Revenue Generated by Customer Demographics')
plt.show()

# %% [markdown]
# The above pie chart shows the revenue generated by each customer demographic

# %%
#Using Decision Tree Regressor to find out the top 5 features that impact the cost of the product as it can learn non-linear relationships between features


model = DecisionTreeRegressor()
model.fit(df2.drop(['Costs','SKU'], axis=1), df2['Costs'])

importances = model.feature_importances_

features = df2.drop(['Costs'], axis=1).columns

sorted_indices = np.argsort(importances)[::-1]

top_5_features = [features[i] for i in sorted_indices[:5]]

print('Top 5 features that impact cost of the product:')
for feature in top_5_features:
    print(f'\t- {feature}')
# Out:
# Top 5 features that impact cost of the product:
# 	- Manufacturing costs
# 	- Lead time
# 	- Stock levels
# 	- Price
# 	- Transportation modes_Sea

# %%
model = DecisionTreeRegressor()
model.fit(df2.drop(['Manufacturing lead time','SKU'], axis=1), df2['Manufacturing lead time'])

importances = model.feature_importances_

features = df2.drop(['Manufacturing lead time'], axis=1).columns

sorted_indices = np.argsort(importances)[::-1]

top_5_features = [features[i] for i in sorted_indices[:5]]

print('Top 5 features that impact manufacturing lead time:')
for feature in top_5_features:
    print(f'\t- {feature}')
# Out:
# Top 5 features that impact manufacturing lead time:
# 	- SKU
# 	- Shipping times
# 	- Availability
# 	- Manufacturing costs
# 	- Lead times
